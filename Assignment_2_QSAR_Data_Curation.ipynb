# %% [markdown]
# # **AI And Biotechnology/Bioinformatics**
#
# ## **AI and Drug Discovery Course: QSAR Modeling**
# This notebook demonstrates how to collect and preprocess bioactivity data from ChEMBL for QSAR modeling

# %% [markdown]
# # **Part 1: Data Collection & Curation**

# %% [markdown]
# **First we need to connect Google Colab with our Google Drive, so that we can have access to our Google drive within Colab.**
#
# This allows us to:
# * Save datasets
# * Reload data across sessions
# * Organize project files

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# **Now create "data" folder in our "Colab Notebooks" folder on Google Drive.**

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %% [markdown]
# ## Install and Import Required Libraries
# We install the ChEMBL web service package so that we can retrieve bioactivity data

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.1)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.1 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.9 MB/s eta 0:00:00
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 6.8 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.3.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %% [markdown]
# # Import Libraries
# * pandas for data handling
# * new_client from chembl for accessing the database

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # Step 1: Search for Traget Protein
#
# ## **Target Identification (p53)**
# Search ChEMBL for the p53 target and select the most relevant entry.

# %%
target = new_client.target
target_query = target.search("p53")
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Mus musculus
# 2               []  Homo sapiens
# 3               []  Homo sapiens
# 4               []  Homo sapiens
#
#                                            pref_name  score  \
# 0                         Cellular tumor antigen p53   16.0
# 1                         Cellular tumor antigen p53   16.0
# 2                 Tumour suppressor protein p53/Mdm4   15.0
# 3                                      MDM2/MDMX-p53   15.0
# 4  Cellular tumor antigen p53/Death-associated pr...   15.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL4096
# 1               False       CHEMBL4164
# 2               False    CHEMBL2221344
# 3               False    CHEMBL3883306
# 4               False    CHEMBL3885543
#
#                                    target_components  \
# 0  [{'accession': 'P04637', 'component_descriptio...
# 1  [{'accession': 'P02340', 'component_descriptio...
# 2  [{'accession': 'P04637', 'component_descriptio...
# 3  [{'accession': 'P04637', 'component_descriptio...
# 4  [{'accession': 'P04637', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN    9606
# 1               SINGLE PROTEIN   10090
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3  PROTEIN-PROTEIN INTERACTION    9606
# 4  PROTEIN-PROTEIN INTERACTION    9606

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=targets)

# %% [markdown]
# **Reterive Bioactivity data for selected target**

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL4096'

# %% [markdown]
# **Now retrieve only bioactivity data for target; **p53(CHEMBL4096)** with reported IC 50  values in nM (nanomolar) unit.**

# %%
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df1 = pd.DataFrame.from_dict(results)
df1.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      2950250                  []
# 1        None             None      2950251                  []
# 2        None             None      2950252                  []
# 3        None             None      2950253                  []
# 4        None             None      2950254                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1052162  Induction of p53 in human HCT116 cells coexpre...
# 1   CHEMBL1052162  Induction of p53 in human HCT116 cells coexpre...
# 2   CHEMBL1052162  Induction of p53 in human HCT116 cells coexpre...
# 3   CHEMBL1052162  Induction of p53 in human HCT116 cells coexpre...
# 4   CHEMBL1052162  Induction of p53 in human HCT116 cells coexpre...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism            target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Cellular tumor antigen p53          9606       None  None
# 1    Homo sapiens  Cellular tumor antigen p53          9606       None  None
# 2    Homo sapiens  Cellular tumor antigen p53          9606       None  None
# 3    Homo sapiens  Cellular tumor antigen p53          9606       None  None
# 4    Homo sapiens  Cellular tumor antigen p53          9606       None  None
#
#    type   units    uo_units upper_value value
# 0  IC50  microM  UO_0000065        None  1.39
# 1  IC50  microM  UO_0000065        None   3.0
# 2  IC50  microM  UO_0000065        None  11.4
# 3  IC50  microM  UO_0000065        None  44.3
# 4  IC50  microM  UO_0000065        None   6.5
#
# [5 rows x 46 columns]

# %%
df1.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# **Finally Save the resulting bioactivity data to a CSV file** **bioactivity_raw_data.csv**.

# %%
df1.to_csv('bioactivity_raw_data.csv', index=False)

# %% [markdown]
# **Now copy "bioactivity_raw_data.csv" file to Google Drive, in foler "data"**

# %%
! cp bioactivity_raw_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 17
# -rw------- 1 root root 17159 Jan 26 20:23 bioactivity_raw_data.csv

# %%
! head bioactivity_raw_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,2950250,[],CHEMBL1052162,Induction of p53 in human HCT116 cells coexpressing pp53TA-luc assessed as inhibition of cell proliferation after 8 hrs by firefly/renilla luciferase reporter assay,B,,,BAO_0000190,BAO_0000219,cell-based format,COc1ccc(C2=N[C@@H](c3ccc(Cl)cc3)[C@@H](c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1,,,CHEMBL1154659,J Med Chem,2009,"{'bei': '10.07', 'le': '0.20', 'lle': '-0.03', 'sei': '7.02'}",CHEMBL191334,NUTLIN-3,CHEMBL191334,5.86,0,http://www.openphacts.org/units/Nanomolar,851968,=,1,1,=,,IC50,nM,,1390.0,CHEMBL4096,Homo sapiens,Cellular tumor antigen p53,9606,,,IC50,microM,UO_0000065,,1.39
# ,,2950251,[],CHEMBL1052162,Induction of p53 in human HCT116 cells coexpressing pp53TA-luc assessed as inhibition of cell proliferation after 8 hrs by firefly/renilla luciferase reporter assay,B,,,BAO_0000190,BAO_0000219,cell-based format,Cc1ccc2c(c1)C1=C(C(c3ccc(Br)cc3)O2)C(c2ccc(Br)cc2)n2ncnc2N1C,,,CHEMBL1154659,J Med Chem,2009,"{'bei': '9.79', 'le': '0.23', 'lle': '-1.18', 'sei': '12.79'}",CHEMBL583413,,CHEMBL583413,5.52,0,http://www.openphacts.org/units/Nanomolar,851988,=,1,1,=,,IC50,nM,,3000.0,CHEMBL4096,Homo sapiens,Cellular tumor antigen p53,9606,,,IC50,microM,UO_0000065,,3.0
# ,,2950252,[],CHEMBL1052162,Induction of p53 in human HCT116 cells coexpressing pp53TA-luc assessed as inhibition of cell proliferation after 8 hrs by firefly/renilla luciferase reporter assay,B,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc2c(cc1F)OC(c1ccc(Br)cc1)C1=C2N(C)c2ncnn2C1c1ccc(Br)cc1,,,CHEMBL1154659,J Med Chem,2009,"{'bei': '8.49', 'le': '0.20', 'lle': '-1.89', 'sei': '11.45'}",CHEMBL584512,,CHEMBL584512,4.94,0,http://www.openphacts.org/units/Nanomolar,852137,=,1,1,=,,IC50,nM,,11400.0,CHEMBL4096,Homo sapiens,Cellular tumor antigen p53,9606,,,IC50,microM,UO_0000065,,11.4
# ,,2950253,[],CHEMBL1052162,Induction of p53 in human HCT116 cells coexpressing pp53TA-luc assessed as inhibition of cell proliferation after 8 hrs by firefly/renilla luciferase reporter assay,B,,,BAO_0000190,BAO_0000219,cell-based format,CN1C2=C(C(c3ccc(Br)cc3)Oc3ccc(F)cc32)C(c2ccc(Br)cc2)n2ncnc21,,,CHEMBL1154659,J Med Chem,2009,"{'bei': '7.66', 'le': '0.18', 'lle': '-2.18', 'sei': '10.08'}",CHEMBL567403,,CHEMBL567403,4.35,0,http://www.openphacts.org/units/Nanomolar,852008,=,1,1,=,,IC50,nM,,44300.0,CHEMBL4096,Homo sapiens,Cellular tumor antigen p53,9606,,,IC50,microM,UO_0000065,,44.3
# ,,2950254,[],CHEMBL1052162,Induction of p53 in human HCT116 cells coexpressing pp53TA-luc assessed as inhibition of cell proliferation after 8 hrs by firefly/renilla luciferase reporter assay,B,,,BAO_0000190,BAO_0000219,cell-based format,CCOc1cccc2c1C1=C(C(c3ccc(Br)cc3)O2)C(c2ccc(Br)cc2)n2ncnc2N1C,,,CHEMBL1154659,J Med Chem,2009,"{'bei': '8.73', 'le': '0.20', 'lle': '-1.60', 'sei': '9.90'}",CHEMBL583626,,CHEMBL583626,5.19,0,http://www.openphacts.org/units/Nanomolar,851995,=,1,1,=,,IC50,nM,,6500.0,CHEMBL4096,Homo sapiens,Cellular tumor antigen p53,9606,,,IC50,microM,UO_0000065,,6.5
# ,,2950255,[],CHEMBL1052162,Induction of p53 in human HCT116 cells coexpressing pp53TA-luc assessed as inhibition of cell proliferation after 8 hrs by firefly/renilla luciferase reporter assay,B,,,BAO_0000190,BAO_0000219,cell-based format,CN1C2=C(C(c3ccc(Cl)cc3)Oc3ccccc32)C(c2ccc(Br)cc2)n2ncnc21,,,CHEMBL1154659,J Med Chem,2009,"{'bei': '9.54', 'le': '0.21', 'lle': '-1.46', 'sei': '11.17'}",CHEMBL567636,,CHEMBL567636,4.82,0,http://www.openphacts.org/units/Nanomolar,852123,=,1,1,=,,IC50,nM,,15000.0,CHEMBL4096,Homo sapiens,Cellular tumor antigen p53,9606,,,IC50,microM,UO_0000065,,15.0
# ,,2950256,[],CHEMBL1052162,Induction of p53 in human HCT116 cells coexpressing pp53TA-luc assessed as inhibition of cell proliferation after 8 hrs by firefly/renilla luciferase reporter assay,B,,,BAO_0000190,BAO_0000219,cell-based format,CN1C2=C(C(c3ccc(Cl)cc3)Oc3ccccc32)C(c2ccc(Cl)cc2)n2ncnc21,,,CHEMBL1154659,J Med Chem,2009,"{'bei': '10.90', 'le': '0.21', 'lle': '-1.14', 'sei': '11.64'}",CHEMBL584299,,CHEMBL584299,5.03,0,http://www.openphacts.org/units/Nanomolar,852039,=,1,1,=,,IC50,nM,,9370.0,CHEMBL4096,Homo sapiens,Cellular tumor antigen p53,9606,,,IC50,microM,UO_0000065,,9.37
# ,,2950270,[],CHEMBL1052166,Induction of p53-Ser15 phosphorylation in human HCT116 cells after 24 hrs,B,,,BAO_0000190,BAO_0000219,cell-based format,COc1ccc(C2=N[C@@H](c3ccc(Cl)cc3)[C@@H](c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1,,,CHEMBL1154659,J Med Chem,2009,"{'bei': '10.32', 'le': '0.20', 'lle': '0.11', 'sei': '7.19'}",CHEMBL191334,NUTLIN-3,CHEMBL191334,6.00,0,http://www.openphacts.org/units/Nanomolar,851968,=,1,1,=,,IC50,nM,,1000.0,CHEMBL4096,Homo sapiens,Cellular tumor antigen p53,9606,,,IC50,microM,UO_0000065,,1.0
# ,,2950272,[],CHEMBL1052166,Induction of p53-Ser15 phosphorylation in human HCT116 cells after 24 hrs,B,,,BAO_0000190,BAO_0000219,cell-based format,Cc1ccc2c(c1)C1=C(C(c3ccc(Br)cc3)O2)C(c2ccc(Br)cc2)n2ncnc2N1C,,,CHEMBL1154659,J Med Chem,2009,"{'bei': '10.63', 'le': '0.25', 'lle': '-0.70', 'sei': '13.90'}",CHEMBL583413,,CHEMBL583413,6.00,0,http://www.openphacts.org/units/Nanomolar,851988,=,1,1,=,,IC50,nM,,1000.0,CHEMBL4096,Homo sapiens,Cellular tumor antigen p53,9606,,,IC50,microM,UO_0000065,,1.0

# %% [markdown]
# # **Step 3: Bioactivity Data Retrieval (IC50)**
# **Retrieve bioactivity data (IC50) for the selected p53 target.**

# %% [markdown]
# **Inspect Missing Values**

# %%
df1["standard_type"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Filter Rows with Valid Bioactivity Values**

# %%
df2 = df1[df1["standard_value"].notna()]
df2.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      2950250                  []
# 1        None             None      2950251                  []
# 2        None             None      2950252                  []
# 3        None             None      2950253                  []
# 4        None             None      2950254                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1052162  Induction of p53 in human HCT116 cells coexpre...
# 1   CHEMBL1052162  Induction of p53 in human HCT116 cells coexpre...
# 2   CHEMBL1052162  Induction of p53 in human HCT116 cells coexpre...
# 3   CHEMBL1052162  Induction of p53 in human HCT116 cells coexpre...
# 4   CHEMBL1052162  Induction of p53 in human HCT116 cells coexpre...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism            target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Cellular tumor antigen p53          9606       None  None
# 1    Homo sapiens  Cellular tumor antigen p53          9606       None  None
# 2    Homo sapiens  Cellular tumor antigen p53          9606       None  None
# 3    Homo sapiens  Cellular tumor antigen p53          9606       None  None
# 4    Homo sapiens  Cellular tumor antigen p53          9606       None  None
#
#    type   units    uo_units upper_value value
# 0  IC50  microM  UO_0000065        None  1.39
# 1  IC50  microM  UO_0000065        None   3.0
# 2  IC50  microM  UO_0000065        None  11.4
# 3  IC50  microM  UO_0000065        None  44.3
# 4  IC50  microM  UO_0000065        None   6.5
#
# [5 rows x 46 columns]

# %% [markdown]
# **Assign Bioactivity Classes**
# Define active, intermediate, and inactive classes based on IC50 values.

# %%
bioactivity_class = []
for value in df2.standard_value:
    value = float(value)
    if value >= 10000:
        bioactivity_class.append("inactive")
    elif value <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %% [markdown]
# **Extract Relevant Columns**

# %%
molecule_ids = df2.molecule_chembl_id.tolist()
canonical_smiles = df2.canonical_smiles.tolist()
standard_values = df2.standard_value.tolist()

# %%
data = list(zip(
    molecule_ids,
    canonical_smiles,
    standard_values,
        bioactivity_class,
))

# %% [markdown]
# **Create Preprocessed bioactivity Dataset**

# %%
df3 = pd.DataFrame(
    data,
    columns=[
        "molecule_chembl_id",
        "canonical_smiles",
        "standard_value",
        "bioactivity_class",
    ]
)
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL191334  COc1ccc(C2=N[C@@H](c3ccc(Cl)cc3)[C@@H](c3ccc(C...
# 1       CHEMBL583413  Cc1ccc2c(c1)C1=C(C(c3ccc(Br)cc3)O2)C(c2ccc(Br)...
# 2       CHEMBL584512  Cc1cc2c(cc1F)OC(c1ccc(Br)cc1)C1=C2N(C)c2ncnn2C...
# 3       CHEMBL567403  CN1C2=C(C(c3ccc(Br)cc3)Oc3ccc(F)cc32)C(c2ccc(B...
# 4       CHEMBL583626  CCOc1cccc2c1C1=C(C(c3ccc(Br)cc3)O2)C(c2ccc(Br)...
#
#   standard_value bioactivity_class
# 0         1390.0      intermediate
# 1         3000.0      intermediate
# 2        11400.0          inactive
# 3        44300.0          inactive
# 4         6500.0      intermediate

# %% [markdown]
# **Remove Compounds without Valid SMILES**. Drop rows with **NaN**, **empty** or **None** SMILES values.

# %%
df3 = df3.dropna(subset=["canonical_smiles"])
df3 = df3[df3["canonical_smiles"].str.lower() != "none"]
df3 = df3[df3["canonical_smiles"].str.strip() != ""]
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL191334  COc1ccc(C2=N[C@@H](c3ccc(Cl)cc3)[C@@H](c3ccc(C...
# 1       CHEMBL583413  Cc1ccc2c(c1)C1=C(C(c3ccc(Br)cc3)O2)C(c2ccc(Br)...
# 2       CHEMBL584512  Cc1cc2c(cc1F)OC(c1ccc(Br)cc1)C1=C2N(C)c2ncnn2C...
# 3       CHEMBL567403  CN1C2=C(C(c3ccc(Br)cc3)Oc3ccc(F)cc32)C(c2ccc(B...
# 4       CHEMBL583626  CCOc1cccc2c1C1=C(C(c3ccc(Br)cc3)O2)C(c2ccc(Br)...
#
#   standard_value bioactivity_class
# 0         1390.0      intermediate
# 1         3000.0      intermediate
# 2        11400.0          inactive
# 3        44300.0          inactive
# 4         6500.0      intermediate

# %% [markdown]
# **Save Preprocessed Bioactivity Data.** Save the cleaned dataset to CSV and copy to Google Drive.

# %%
df3.to_csv("bioactivity_preprocessed_data.csv", index=False)

# !cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
# !ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_preprocessed_data.csv  bioactivity_raw_data.csv

# %% [markdown]
# ## **End of Part 1: Data Collection and Curation**
